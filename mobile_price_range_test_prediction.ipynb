# %% [markdown]
# # predict mobile price range from test dataset using model

# %%
import pandas as pd
import joblib

# %%
test_df = pd.read_csv("datasets/test.csv")

# %%
test_df.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
test_df.shape
# Out:
# (1000, 21)

# %%
x=test_df.drop('id',axis=1)

# %%
scaler= joblib.load('scaler.h5')
model=joblib.load('model.h5')

# %%
scaled_x_test = scaler.transform(x)
scaled_x_test
# Out:
# array([[-0.44505984,  1.0100505 ,  0.34046327, ..., -1.78686097,
#          0.99401789, -1.01409939],
#        [-0.90487356,  1.0100505 , -1.2530642 , ...,  0.55964063,
#         -1.00601811, -1.01409939],
#        [ 1.29403758,  1.0100505 ,  1.56625363, ..., -1.78686097,
#          0.99401789,  0.98609664],
#        ...,
#        [-0.12182446, -0.9900495 , -0.14985287, ...,  0.55964063,
#         -1.00601811, -1.01409939],
#        [ 0.67032987,  1.0100505 , -1.2530642 , ..., -1.78686097,
#          0.99401789, -1.01409939],
#        [ 0.07166151,  1.0100505 , -1.2530642 , ...,  0.55964063,
#         -1.00601811,  0.98609664]])

# %%
predict_price_range = model.predict(scaled_x_test)

# %%
predict_price_range
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2, 1, 3,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 1, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 1, 3, 1, 1, 3, 3, 3, 0, 1, 1, 1,
#        2, 3, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 1, 3, 0, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 2, 2, 1, 2, 2, 1, 2, 1, 2, 1, 0, 0, 3, 0, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 2, 3, 0, 0, 3, 2, 1, 2, 0, 3, 2, 2, 2, 0, 2,
#        2, 1, 3, 1, 1, 0, 3, 2, 1, 2, 1, 3, 2, 3, 3, 3, 2, 3, 2, 3, 1, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 2, 1, 0, 1,
#        0, 0, 1, 2, 1, 0, 0, 1, 1, 2, 2, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        2, 3, 1, 2, 3, 2, 3, 2, 2, 1, 1, 0, 1, 2, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 3, 3, 1, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 3, 1, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 3, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 0, 2, 3, 1, 1, 3, 2, 1, 3, 0, 0, 2, 1, 0, 3, 2, 3,
# ...

# %% [markdown]
# #### add prediction on the test_df

# %%
test_df['predicted_price_range'] = predict_price_range
test_df.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0    0.1        193  ...        226      1412  3476    12     7          2
# 1    0.8        191  ...        746       857  3895     6     0          7
# 2    0.9        186  ...       1270      1366  2396    17    10         10
# 3    0.5         96  ...        295      1752  3893    10     0          7
# 4    0.5        108  ...        749       810  1773    15     8          7
#
#    three_g  touch_screen  wifi  predicted_price_range
# ...

# %% [markdown]
# #### save prediction on new csv file

# %%
predict_test = test_df[['id','predicted_price_range']]
predict_test.head()
# Out:
#    id  predicted_price_range
# 0   1                      3
# 1   2                      3
# 2   3                      2
# 3   4                      3
# 4   5                      1

# %%
predict_test.to_csv('datasets\predict_test.csv',index=False)

# %%
price_pred_df = pd.read_csv("datasets/predict_test.csv")

# %%
price_pred_df.head()
# Out:
#    id  predicted_price_range
# 0   1                      3
# 1   2                      3
# 2   3                      2
# 3   4                      3
# 4   5                      1
